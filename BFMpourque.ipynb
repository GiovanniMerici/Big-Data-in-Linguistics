# %%
import pandas as pd
import matplotlib as plt
df = pd.read_excel ('BFMpourque.xlsx')

# %%
df1 = df.drop(columns=['ContexteGauche','ContexteDroit'])

# %%
df1

df_p1=df1[(df1['Forme']=="pour ce que")| (df1['Forme']=="pour ce qu'") | (df1['Forme']=="por ce que") | (df1['Forme']=="por ce qu'") | (df1['Forme']=="Por ce que") | (df1['Forme']=="Pour ce que") | (df1['Forme']=="pour ce qu'") | (df1['Forme']=="pour che que") | (df1['Forme']=="Por ce qu'") | (df1['Forme']=="Pour ce qu'") | (df1['Forme']=="pour che qu'") | (df1['Forme']=="por qu'") | (df1['Forme']=="por ce ke") | (df1['Forme']=="pur ce que") | (df1['Forme']=="Pur ce que") | (df1['Forme']=="Pour che que") | (df1['Forme']=="pur ce qu'") | (df1['Forme']=="Pur ce qu'") | (df1['Forme']=="por che qu'") | (df1['Forme']=="Pour che qu'") | (df1['Forme']=="por che que") | (df1['Forme']=="POUR CE que") | (df1['Forme']=="por ce k'") | (df1['Forme']=="por ce quë") | (df1['Forme']=="Por che que") | (df1['Forme']=="Pour ce ke") | (df1['Forme']=="Pour ce Que")]
df_p2=df1[(df1['Forme']=="por que") | (df1['Forme']=="por ke")| (df1['Forme']=="Por que") | (df1['Forme']=="pour que") | (df1['Forme']=="Por qu'") | (df1['Forme']=="Por ke") | (df1['Forme']=="pour qu'") | (df1['Forme']=="pur Qu'") | (df1['Forme']=="pur que")]

df_p1
df_p2
# Out:
#       Date     Forme
# 32    1183   por que
# 33    1183   por que
# 42    1200   por que
# 44    1200   por que
# 46    1200   Por que
# 47    1200   pur que
# 49    1200   por que
# 50    1200   por que
# 54    1200   por que
# 55    1200   Por que
# 57    1200   por que
# 68    1200    por ke
# 69    1200    por ke
# 72    1200    por ke
# 75    1200    por ke
# 79    1200    por ke
# 80    1200    por ke
# 81    1200    Por ke
# 83    1200    por ke
# 84    1200    por ke
# 86    1200    por ke
# 87    1200    por ke
# 96    1216  pour qu'
# 208   1235   Por qu'
# 227   1235   Por qu'
# 249   1235   por que
# 412   1250  pour que
# 421   1250  pour que
# 424   1250   por que
# 465   1275   por que
# 568   1283   por que
# 605   1283   Por que
# 658   1285   por que
# 1446  1380   pur Qu'
# 1924  1404  pour que

# %%
df_p11 = df_p1.drop(columns=['Forme'])
df_p11.rename(columns = {'Date':'Présence du pronom démonstratif "ce"'}, inplace = True)
df_p21 = df_p2.drop(columns=['Forme'])
df_p21.rename(columns = {'Date':'Absence du pronom démonstratif "ce"'}, inplace = True)

# %% [markdown]
# Graphs : démonstratif "ce" présent dans le paradigme de "pour que"

# %%
print('Graphs : démonstratif "ce" présent dans le paradigme de "pour que"')
df_p11.plot(kind='kde', ylim=(0,0.015), xlim=(1150,1799), xlabel='date', title="Présence du pronom démonstratif 'ce'", figsize=(10,5), grid=True, colormap='Greens_r')
df_p11.plot(kind='hist', grid=True, colormap='Greens_r', figsize=(10,5))
df_p11.plot(kind='box', grid=True, colormap='Greens_r', figsize=(10,5), patch_artist=True)
# Out:
# Graphs : démonstratif "ce" présent dans le paradigme de "pour que"
# <AxesSubplot:>

# %% [markdown]
# Graphs: démonstratif "ce" absent dans le paradigme de "pour que"

# %%
print('Graphs: démonstratif "ce" absent dans le paradigme de "pour que"')
df_p21.plot(kind='kde', ylim=(0,0.015), xlim=(1150,1799), xlabel='date', title="Absence du pronom démonstratif 'ce'", figsize=(10,5), grid=True, colormap='rainbow')
df_p21.plot(kind='hist', grid=True, colormap='rainbow', figsize=(10,5))
df_p21.plot(kind='box', grid=True, colormap='rainbow', figsize=(10,5), patch_artist=True)
# Out:
# Graphs: démonstratif "ce" absent dans le paradigme de "pour que"
# <AxesSubplot:>

# %%
plot=input('which plot?')
if plot=='all':
    ax =df_p11.plot(kind='kde', colormap='ocean')
    df_p21.plot(kind='kde',ax=ax, colormap='jet', grid=True, figsize=(10,5))
    ax =df_p11.plot(kind='hist', colormap='ocean')
    df_p21.plot(kind='hist',ax=ax, colormap='jet', grid=True, figsize=(10,5))
    ax =df_p11.plot(kind='box', colormap='ocean', patch_artist=True)
    df_p21.plot(kind='box',ax=ax, colormap='jet', grid=True, figsize=(10,5), patch_artist=True)
    
elif plot=='box':
    ax =df_p11.plot(kind=plot, colormap='ocean', patch_artist=True,  legend=True, subplots=True)
    df_p21.plot(kind=plot ,ax=ax, colormap='jet', grid=True, figsize=(10,5), patch_artist=True, legend=True, subplots=True)
else:
    ax =df_p11.plot(kind=plot, colormap='ocean')
    df_p21.plot(kind=plot ,ax=ax, colormap='jet', grid=True, figsize=(10,5))
# Out:
# which plot? all
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-47e41a041d82> in <module>
#       6     df_p21.plot(kind='hist',ax=ax, colormap='jet', grid=True, figsize=(10,5))
#       7     ax =df_p11.plot(kind='box', colormap='ocean', patch_artist=True)
# ----> 8     df_p21.plot(kind='box',ax=ax, colormap='jet', grid=True, figsize=(10,5), patch_artist=True)
#       9
#      10 elif plot=='box':
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     953                     data.columns = label_name
#     954
# --> 955         return plot_backend.plot(data, kind=kind, **kwargs)
#     956
#     957     __call__.__doc__ = __doc__
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     278         self._compute_plot_data()
#     279         self._setup_subplots()
# --> 280         self._make_plot()
#     281         self._add_table()
#     282         self._make_legend()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/boxplot.py in _make_plot(self)
#     154             if not self.use_index:
#     155                 labels = [pprint_thing(key) for key in range(len(labels))]
# --> 156             self._set_ticklabels(ax, labels)
#     157
#     158     def _set_ticklabels(self, ax: "Axes", labels):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/boxplot.py in _set_ticklabels(self, ax, labels)
#     158     def _set_ticklabels(self, ax: "Axes", labels):
#     159         if self.orientation == "vertical":
# --> 160             ax.set_xticklabels(labels)
#     161         else:
#     162             ax.set_yticklabels(labels)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in wrapper(self, *args, **kwargs)
#      61
#      62         def wrapper(self, *args, **kwargs):
# ---> 63             return get_method(self)(*args, **kwargs)
#      64
#      65         wrapper.__module__ = owner.__module__
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     449                 "parameter will become keyword-only %(removal)s.",
#     450                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 451         return func(*args, **kwargs)
#     452
#     453     return wrapper
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axis.py in _set_ticklabels(self, labels, fontdict, minor, **kwargs)
#    1794         if fontdict is not None:
#    1795             kwargs.update(fontdict)
# -> 1796         return self.set_ticklabels(labels, minor=minor, **kwargs)
#    1797
#    1798     @cbook._make_keyword_only("3.2", "minor")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axis.py in set_ticklabels(self, ticklabels, minor, **kwargs)
#    1715             # remove all tick labels, so only error for > 0 ticklabels
#    1716             if len(locator.locs) != len(ticklabels) and len(ticklabels) != 0:
# -> 1717                 raise ValueError(
#    1718                     "The number of FixedLocator locations"
#    1719                     f" ({len(locator.locs)}), usually from a call to"
#
# ValueError: The number of FixedLocator locations (2), usually from a call to set_ticks, does not match the number of ticklabels (1).
