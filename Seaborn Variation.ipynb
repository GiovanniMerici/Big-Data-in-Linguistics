# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(font_scale=40)

# %%
#VARIATIONQUECEQUEdansPARCEQUEetPOURQUE
dfFRpo = pd.read_excel ('FRANTEXTpourque.xlsx') 
dfBFMpo = pd.read_excel ('BFMpourque.xlsx')
dfFRpa = pd.read_excel ('FRANTEXTparceque.xlsx')
dfBFMpa = pd.read_excel ('BFMparceque.xlsx')

# %%
dfBFMpo_withce=dfBFMpo[(dfBFMpo['Forme']=="pour ce que") | (dfBFMpo['Forme']=="pource qu'") | (dfBFMpo['Forme']=="por ce que") | (dfBFMpo['Forme']=="por ce qu'")| (dfBFMpo['Forme']=="Por ce que") | (dfBFMpo['Forme']=="Pour ce que") | (dfBFMpo['Forme']=="pour ce qu'") | (dfBFMpo['Forme']=="pour che que") | (dfBFMpo['Forme']=="Por ce qu'") | (dfBFMpo['Forme']=="Pour ce qu'") | (dfBFMpo['Forme']=="pour che qu'") | (dfBFMpo['Forme']=="por ce ke") | (dfBFMpo['Forme']=="pur ce que") | (dfBFMpo['Forme']=="Pur ce que") | (dfBFMpo['Forme']=="Pour che que") | (dfBFMpo['Forme']=="pur ce qu'") | (dfBFMpo['Forme']=="Pur ce qu'") | (dfBFMpo['Forme']=="por che qu'") | (dfBFMpo['Forme']=="Pour che qu'") | (dfBFMpo['Forme']=="por che que") | (dfBFMpo['Forme']=="POUR CE que") | (dfBFMpo['Forme']=="por ce k'") | (dfBFMpo['Forme']=="por ce quë") | (dfBFMpo['Forme']=="Por che que") | (dfBFMpo['Forme']=="Pour ce ke") | (dfBFMpo['Forme']=="Pour ce Que")]
dfBFMpo_withoutce=dfBFMpo[(dfBFMpo['Forme']=="por qu'") | (dfBFMpo['Forme']=="por que") | (dfBFMpo['Forme']=="por ke") | (dfBFMpo['Forme']=="Por que") | (dfBFMpo['Forme']=="pour que") | (dfBFMpo['Forme']=="Por qu'") | (dfBFMpo['Forme']=="Por ke") | (dfBFMpo['Forme']=="pour qu'") | (dfBFMpo['Forme']=="pur Qu'") | (dfBFMpo['Forme']=="pur que")]

dfFRpo_withce=dfFRpo[(dfFRpo['Forme']=="pource que")| (dfFRpo['Forme']=="Pource que") | (dfFRpo['Forme']=="pource qu'") | (dfFRpo['Forme']=="Pource qu'") | (dfFRpo['Forme']=="pourcequ'") | (dfFRpo['Forme']=="Pourcequ'") | (dfFRpo['Forme']=="pourceque") | (dfFRpo['Forme']=="Pourceque") | (dfFRpo['Forme']=="pour ce que") | (dfFRpo['Forme']=="Pour ce que") | (dfFRpo['Forme']=="pour che que") | (dfFRpo['Forme']=="Pour che que") | (dfFRpo['Forme']=="por ce que") | (dfFRpo['Forme']=="Por ce que") | (dfFRpo['Forme']=="pour che qu'") | (dfFRpo['Forme']=="Pour che qu'") | (dfFRpo['Forme']=="por ce qu") | (dfFRpo['Forme']=="Por ce qu") | (dfFRpo['Forme']=="pour che qu") | (dfFRpo['Forme']=="Pour che qu") | (dfFRpo['Forme']=="pour ce qu") | (dfFRpo['Forme']=="Pour ce qu")]
dfFRpo_withoutce=dfFRpo[(dfFRpo['Forme']=="pour que") | (dfFRpo['Forme']=="Pour que")| (dfFRpo['Forme']=="pour qu'") | (dfFRpo['Forme']=="Pour qu'") | (dfFRpo['Forme']=="por qu'") | (dfFRpo['Forme']=="Por qu'") | (dfFRpo['Forme']=="por que") | (dfFRpo['Forme']=="Por que") | (dfFRpo['Forme']=="pou que")]

# %%
dfBFMpa_withce=dfBFMpa[(dfBFMpa['Forme']=="par ce que") | (dfBFMpa['Forme']=="par ce ke") | (dfBFMpa['Forme']=="par ce qu'") | (dfBFMpa['Forme']=="Par ce que") | (dfBFMpa['Forme']=="par che que") | (dfBFMpa['Forme']=="Par ce qu'") | (dfBFMpa['Forme']=="par che que")]
dfBFMpa_withoutce=dfBFMpa[(dfBFMpa['Forme']=="par ke") | (dfBFMpa['Forme']=="par k'") | (dfBFMpa['Forme']=="par que") | (dfBFMpa['Forme']=="Par ke") | (dfBFMpa['Forme']=="Par qu'") | (dfBFMpa['Forme']=="par qu'")]

dfFRpa_withce=dfFRpa[(dfFRpa['Forme']=="parce qu'") | (dfFRpa['Forme']=="Parce qu'") | (dfFRpa['Forme']=="parce que") | (dfFRpa['Forme']=="Parce que") | (dfFRpa['Forme']=="parceque") | (dfFRpa['Forme']=="Parceque") | (dfFRpa['Forme']=="parcequ") | (dfFRpa['Forme']=="Parcequ") | (dfFRpa['Forme']=="par ce que") | (dfFRpa['Forme']=="par che que") | (dfFRpa['Forme']=="parcequ'")]
dfFRpa_withoutce=dfFRpa[(dfFRpa['Forme']=="par que") | (dfFRpa['Forme']=="par qu'") | (dfFRpa['Forme']=="Par qu'") | (dfFRpa['Forme']=="par quez") | (dfFRpa['Forme']=="paske") | (dfFRpa['Forme']=="par qu")]

# %%
sns.set(rc={'figure.figsize':(20,10)})
sns.set_style('darkgrid')
#'axes.facecolor':'lightblue', 'figure.facecolor':'lightgreen'

sns.set_color_codes()
sns.kdeplot(dfBFMpo['Date'], color='darkmagenta').set(title="Evolution de la variation 'que/ce que' dans la forme 'pour que' d'après les données de la BFM")
sns.distplot(dfBFMpo_withce['Date'], color='fuchsia')
#ax = sns.distplot(dfBFMpo_withce['Date'])
#[line.set_linestyle("--") for line in ax.lines] 
sns.distplot(dfBFMpo_withoutce['Date'], color='lightpink')
sns.rugplot(dfBFMpo_withce['Date'], color='fuchsia')
sns.rugplot(dfBFMpo_withoutce['Date'], color='lightpink')

plt.legend(labels=["Forme en 'ce que'", "Forme en 'que'", "Evolution générale de 'pour(ce)que'"], ncol=3, title ="Légende", fontsize = 'large', title_fontsize = "15", loc = 2, bbox_to_anchor = (0,1))
plt.xlim(1100,1505)
plt.xticks(np.arange(1100,1505,50))
#plt.savefig('seabornVariationQueCeQuePourQueBFM.png', dpi=1080)
# Out:
# C:\Users\cmonm\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\cmonm\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ([<matplotlib.axis.XTick at 0x18b272112d0>,
# ...
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
# ...

# %%
sns.set(rc={'figure.figsize':(20,10), 'grid.color':'black', 'axes.facecolor':'white', 'figure.facecolor':'lightgrey'})

#'axes.facecolor':'lightblue', 'figure.facecolor':'lightgreen'

sns.set_color_codes()

sns.kdeplot(dfBFMpo['Date'], color='darkmagenta', linestyle="--")
#.set(title="Evolution de la variation 'que/ce que' dans les formes 'pour que' et 'parce que' d'après les données de la BFM et de Frantext")
sns.kdeplot(dfFRpo['Date'], color='darkmagenta')

sns.distplot(dfBFMpo_withce['Date'], color='fuchsia', kde_kws={"linestyle":"--"}, hist_kws={"linestyle":"--", 'edgecolor':'black'})
sns.distplot(dfFRpo_withce['Date'], color='fuchsia')

sns.distplot(dfBFMpo_withoutce['Date'], color='lightpink', kde_kws={"linestyle":"--"}, hist_kws={"linestyle":"--", 'edgecolor':'black'})
sns.distplot(dfFRpo_withoutce['Date'], color='lightpink')

sns.rugplot(dfBFMpo_withce['Date'], color='fuchsia', linestyle = "--")
sns.rugplot(dfBFMpo_withoutce['Date'], color='lightpink',linestyle="--")
sns.rugplot(dfFRpo_withce['Date'], color='fuchsia')
sns.rugplot(dfFRpo_withoutce['Date'], color='lightpink')

plt.legend(labels=["Evolution générale de 'pour(ce)que' BFM", "Evolution générale de 'pour(ce)que' Frantext", "Formes en 'ce que' BFM", "Formes en 'ce que' Frantext", "Formes en 'que' BFM", "Formes en 'que' Frantext"], borderpad=1, shadow=True, fancybox=True, ncol=3, title ="Légende", fontsize = 'large', title_fontsize = "15", loc = 2, bbox_to_anchor = (0,1))
plt.xlim(1100,1799)
plt.xlabel('Date', fontsize=15)
plt.xticks(np.arange(1100,1799,50), fontsize=15)
plt.ylabel('Density', fontsize=15)
plt.yticks(fontsize=15)
#plt.savefig('seabornVariationQueCeQuePourQueBFMetFRANTEXT.png', dpi=1080)
# Out:
# C:\Users\cmonm\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\cmonm\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
sns.set(rc={'figure.figsize':(20,10), 'grid.color':'black', 'axes.facecolor':'white', 'figure.facecolor':'lightgrey'})

#'axes.facecolor':'lightblue', 'figure.facecolor':'lightgreen'

sns.set_color_codes()

sns.kdeplot(dfBFMpa['Date'], color='darkblue', linestyle="--")
#.set(title="Evolution de la variation 'que/ce que' dans la forme 'parce que' d'après les données de la BFM et de Frantext")
sns.kdeplot(dfFRpa['Date'], color='darkblue')

sns.distplot(dfBFMpa_withce['Date'], color='dodgerblue', kde_kws={"linestyle":"--"}, hist_kws={"linestyle":"--", 'edgecolor':'black'}, rug_kws={"linestyle":"--"})
sns.distplot(dfFRpa_withce['Date'], color='dodgerblue')

sns.distplot(dfBFMpa_withoutce['Date'], color='cyan', kde_kws={"linestyle":"--"}, hist_kws={"linestyle":"--", 'edgecolor':'black'}, rug_kws={"linestyle":"."})
sns.distplot(dfFRpa_withoutce['Date'], color='cyan')

sns.rugplot(dfBFMpa_withce['Date'], color='dodgerblue')
sns.rugplot(dfBFMpa_withoutce['Date'], color='cyan')
sns.rugplot(dfFRpa_withce['Date'], color='dodgerblue')
sns.rugplot(dfFRpa_withoutce['Date'], color='cyan')

plt.legend(labels=["Evolution générale de 'par(ce)que' BFM", "Evolution générale de 'par(ce)que' Frantext", "Formes en 'ce que' BFM", "Formes en 'ce que' Frantext", "Formes en 'que' BFM", "Formes en 'que' Frantext"], borderpad=1, shadow=True, fancybox=True, ncol=3, title ="Légende", fontsize = 'large', title_fontsize = "15", loc = 2, bbox_to_anchor = (0,1))
plt.xlim(1100,1799)
plt.ylim(0,0.01)
plt.xlabel('Date', fontsize=15)
plt.xticks(np.arange(1100,1799,50), fontsize=15)
plt.ylabel('Density', fontsize=15)
plt.yticks(fontsize=15)
#plt.savefig('seabornVariationQueCeQueParceQueBFMetFRANTEXTzoom.png', dpi=1080)
# Out:
# C:\Users\cmonm\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\cmonm\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
sns.set(rc={'figure.figsize':(20,10), 'grid.color':'black', 'axes.facecolor':'white', 'figure.facecolor':'lightgrey'})

#'axes.facecolor':'lightblue', 'figure.facecolor':'lightgreen'

sns.set_color_codes()

sns.kdeplot(dfBFMpo['Date'], color='darkmagenta')
#.set(title="Evolution de la variation 'que/ce que' dans les formes 'pour que' et 'parce que' d'après les données de la BFM")
sns.kdeplot(dfBFMpa['Date'], color='darkblue', linestyle="-.")

sns.distplot(dfBFMpo_withce['Date'], color='fuchsia')
sns.distplot(dfBFMpa_withce['Date'], color='dodgerblue', kde_kws={"linestyle":"-."}, hist_kws={"linestyle":"-.", 'edgecolor':'black'})

sns.distplot(dfBFMpo_withoutce['Date'], color='lightpink')
sns.distplot(dfBFMpa_withoutce['Date'], color='cyan', kde_kws={"linestyle":"-."}, hist_kws={"linestyle":"-.", 'edgecolor':'black'})

sns.rugplot(dfBFMpo_withce['Date'], color='fuchsia')
sns.rugplot(dfBFMpo_withoutce['Date'], color='lightpink')
sns.rugplot(dfBFMpa_withce['Date'], color='dodgerblue', linestyle="-.")
sns.rugplot(dfBFMpa_withoutce['Date'], color='cyan', linestyle="-.")

plt.legend(labels=["Evolution générale de 'pour(ce)que'", "Evolution générale de 'parce(ce)que'", "Formes de 'pour que' en 'ce que'", "Formes de 'parce que' en 'ce que'", "Formes de 'pour que' en 'que'", "Formes de 'parce que' en 'que'"], borderpad=1, shadow=True, fancybox=True, ncol=3, title ="Légende", fontsize = 'large', title_fontsize = "15", loc = 2, bbox_to_anchor = (0,1))
plt.xlim(1100,1505)
plt.ylim(0,0.025)
plt.xlabel('Date', fontsize=15)
plt.xticks(np.arange(1100,1505,50), fontsize=15)
plt.ylabel('Density', fontsize=15)
plt.yticks(fontsize=15)
#plt.savefig('seabornVariationQueCeQuePourQueParceQueBFMzoom.png', dpi=1080)
# Out:
# C:\Users\cmonm\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\cmonm\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
sns.set(rc={'figure.figsize':(20,10), 'grid.color':'black', 'axes.facecolor':'white', 'figure.facecolor':'lightgrey'})

#'axes.facecolor':'lightblue', 'figure.facecolor':'lightgreen'

sns.set_color_codes()

sns.kdeplot(dfFRpo['Date'], color='darkmagenta')
#.set(title="Evolution de la variation 'que/ce que' dans les formes 'pour que' et 'parce que' d'après les données de Frantext")
sns.kdeplot(dfFRpa['Date'], color='darkblue', linestyle="-.")

sns.distplot(dfFRpo_withce['Date'], color='fuchsia')
sns.distplot(dfFRpa_withce['Date'], color='dodgerblue', kde_kws={"linestyle":"-."}, hist_kws={"linestyle":"-.", 'edgecolor':'black'})

sns.distplot(dfFRpo_withoutce['Date'], color='lightpink')
sns.distplot(dfFRpa_withoutce['Date'], color='cyan', kde_kws={"linestyle":"-."}, hist_kws={"linestyle":"-.", 'edgecolor':'black'})

sns.rugplot(dfFRpo_withce['Date'], color='fuchsia')
sns.rugplot(dfFRpo_withoutce['Date'], color='lightpink')
sns.rugplot(dfFRpa_withce['Date'], color='dodgerblue', linestyle="-.")
sns.rugplot(dfFRpa_withoutce['Date'], color='cyan', linestyle="-.")

plt.legend(labels=["Evolution générale de 'pour(ce)que'", "Evolution générale de 'parce(ce)que'", "Formes de 'pour que' en 'ce que'", "Formes de 'parce que' en 'ce que'", "Formes de 'pour que' en 'que'", "Formes de 'parce que' en 'que'"], borderpad=1, shadow=True, fancybox=True, ncol=3, title ="Légende", fontsize = 'large', title_fontsize = "15", loc = 2, bbox_to_anchor = (0,1))
plt.xlim(1100,1799)
plt.xlabel('Date', fontsize=15)
plt.xticks(np.arange(1100,1799,50), fontsize=15)
plt.ylabel('Density', fontsize=15)
plt.yticks(fontsize=15)
#plt.savefig('seabornVariationQueCeQuePourQueParceQueFRANTEXT.png', dpi=1080)
# Out:
# C:\Users\cmonm\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\cmonm\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
sns.set(rc={'figure.figsize':(20,10), 'grid.color':'black', 'axes.facecolor':'white', 'figure.facecolor':'lightgrey'})

#'axes.facecolor':'lightblue', 'figure.facecolor':'lightgreen'

sns.set_color_codes()

sns.boxplot(dfFRpo['Date'], color='darkmagenta')
sns.stripplot(dfFRpo['Date'], marker="D", alpha=0.3, color="sandybrown")

plt.legend(labels=["Evolution générale de 'pour(ce)que'", "Evolution générale de 'parce(ce)que'", "Formes de 'pour que' en 'ce que'", "Formes de 'parce que' en 'ce que'", "Formes de 'pour que' en 'que'", "Formes de 'parce que' en 'que'"], borderpad=1, shadow=True, fancybox=True, ncol=3, title ="Légende", fontsize = 'large', title_fontsize = "15", loc = 2, bbox_to_anchor = (0,1))

plt.xlim(1100,1799)
plt.xlabel('Date', fontsize=15)
plt.xticks(np.arange(1100,1799,50), fontsize=15)
# Out:
# C:\Users\cmonm\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\cmonm\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ([<matplotlib.axis.XTick at 0x18b8b015180>,
# ...
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
# ...

# %%
sns.set(rc={'figure.figsize':(20,10), 'grid.color':'black', 'axes.facecolor':'white', 'figure.facecolor':'lightgrey'})

#'axes.facecolor':'lightblue', 'figure.facecolor':'lightgreen'

sns.set_color_codes()

sns.boxplot(y=dfFRpo['Date'], orient='v', color='darkmagenta')
sns.stripplot(y=dfFRpo['Date'], marker="D", jitter=0.05, linewidth=1, alpha=0.3, color="whitesmoke")

#plt.xlim(1100,1799)
#plt.xlabel('Date', fontsize=15)
#plt.xticks(np.arange(1100,1799,50), fontsize=15)
# Out:
# <AxesSubplot:ylabel='Date'>
