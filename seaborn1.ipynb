# %% [markdown]
# <a href="https://colab.research.google.com/github/GiovanniMerici/Big-Data-in-Linguistics/blob/main/seaborn1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_excel ('BFMpourque.xlsx')
import seaborn as sns
sns.set_theme()
sns.set_color_codes()
sns.histplot(df['Date'],color='g')
plt.legend(labels=["trial1"], title = "Legend of the gods", fontsize = 'large', title_fontsize = "10", loc = 2, bbox_to_anchor = (1,1))

# %% [markdown]
# Demo of functs

# %%
sns.set(rc={'figure.figsize':(20,10),'axes.facecolor':'lightblue', 'figure.facecolor':'lightgreen'})
plt.subplot(2,1,1)
sns.distplot(df['Date'], color='r').set(title='Title of a plot')
sns.kdeplot(df['Date'], color='b')
plt.legend(labels=["trial1"], title = "Legend of the gods", fontsize = 'large', title_fontsize = "10", loc = 2, bbox_to_anchor = (1,1))
plt.ylim(0,0.008)
plt.xlim(1000,1800)
plt.xticks(np.arange(1000,1800,50))
plt.subplot(2,1,2)
sns.histplot(df['Date'],color='g')
plt.legend(labels=["trial1"], title = "Legend of the gods", fontsize = 'large', title_fontsize = "10", loc = 2, bbox_to_anchor = (1,1))
#plt.savefig('seaborn.png', dpi=2400)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.rugplot(df['Date'], color='r').set(title='Title of a plot')
sns.histplot(df['Date'], color='b')
plt.legend(labels=["trial1"], title = "Legend of the gods", fontsize = 'large', title_fontsize = "10", loc = 2, bbox_to_anchor = (1,1))

# %% [markdown]
# different Dataframes

# %%
sns.distplot(df_pqe['Date'], color='r').set(title='Title of a plot')
sns.distplot(df_pqap['Date'], color='b')
plt.legend(labels=["pqe",'pqap'], title = "Legend of the gods", fontsize = 'large', title_fontsize = "10", loc = 2, bbox_to_anchor = (1,1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-0157f95b543c> in <module>()
# ----> 1 sns.distplot(df_pqe['Date'], color='r').set(title='Title of a plot')
#       2 sns.distplot(df_pqap['Date'], color='b')
#       3 plt.legend(labels=["pqe",'pqap'], title = "Legend of the gods", fontsize = 'large', title_fontsize = "10", loc = 2, bbox_to_anchor = (1,1))
#
# NameError: name 'df_pqe' is not defined

# %%
from google.colab import files
sns.set(rc={'figure.figsize':(20,20),'axes.facecolor':'grey', 'figure.facecolor':'white'})

plt.subplot(3,1,1)
plt.xlabel('xlabel', fontsize=20)
plt.ylabel('Density', fontsize=20)
plt.xticks(fontsize=20)
plt.xticks(fontsize=20)
plt.xlim(1100,1800)
sns.distplot(df['Date'])
sns.rugplot(df['Date'], color='yellow')
plt.legend(labels=["trial1"], title = "Legend of the gods", fontsize = 'large', title_fontsize = "10", loc = 2, bbox_to_anchor = (1,1))
plt.subplot(3,1,2)
plt.xlim(1100,1800)
plt.xlabel('xlabel', fontsize=20)
plt.xticks(fontsize=20)
sns.violinplot(x=df['Date'], orient='h')
sns.stripplot(df['Date'], color='yellow', jitter=0.05, linewidth=0.5)
plt.legend(labels=["trial1"], title = "Legend of the gods", fontsize = 'large', title_fontsize = "10", loc = 2, bbox_to_anchor = (1,1))
plt.subplot(3,1,3)
plt.xlim(1100,1800)
plt.xlabel('xlabel', fontsize=20)
plt.xticks(fontsize=20)
sns.boxplot(x=df['Date'], orient='h')
sns.stripplot(x=df['Date'], color='yellow', jitter=0.05, linewidth=0.5)
plt.legend(labels=["trial1"], title = "Legend of the gods", fontsize = 'large', title_fontsize = "10", loc = 2, bbox_to_anchor = (1,1))
plt.savefig("seaborn.png")
files.download("seaborn.png")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
